# %% [markdown]
# Question 1 : What is Information Gain, and how is it used in Decision Trees?

# %% [markdown]
# Answer -
#
# Information Gain is the decrease in entropy (or impurity) after a dataset is split on an attribute3. It measures the quality of the split.$$\text{Information Gain}(\text{S}, \text{A}) = \text{Entropy}(\text{S}) - \sum_{v \in \text{Values}(\text{A})} \frac{|\text{S}_v|}{|\text{S}|} \cdot \text{Entropy}(\text{S}_v)$$
#
# Use in Decision Trees: Decision Tree algorithms, such as ID3, use Information Gain to determine the most effective attribute for splitting a node. The attribute that yields the highest Information Gain (i.e., the largest reduction in impurity) is chosen as the splitting criterion at that node. This greedy, recursive process continues until a stopping condition is met

# %% [markdown]
# Question 2: What is the difference between Gini Impurity and Entropy?

# %% [markdown]
# Answer -
#
# Gini Impurity measures how often a randomly chosen element would be misclassified if it were labeled randomly according to class distribution.
#
#
# Entropy measures the amount of disorder or uncertainty in the data.
#
# Gini is calculated as 1 − Σ(p²) and
#
# Entropy as −Σ(p × log₂p).
#
# Gini is faster (no logarithms), while Entropy is more theoretical.
# Both are used to find the best split in decision trees, and they usually give similar results.

# %% [markdown]
# Question 3:What is Pre-Pruning in Decision Trees?

# %% [markdown]
# Answer -
#
# Pre-Pruning (or Early Stopping) is a technique used to prevent Decision Trees from overfitting the training data.
#
# Instead of building the full tree and then pruning it back (Post-Pruning), pre-pruning involves stopping the tree construction process before it becomes fully grown and perfectly fits the training data.
#
# Common stopping criteria for pre-pruning include:
#
#
# Maximum Depth: Restricting the maximum depth of the tree.
#
#
# Minimum Samples Split: Requiring a minimum number of samples in a node before a split is attempted.
#
#
# Minimum Samples Leaf: Requiring a minimum number of samples in any resulting leaf node.
#
#
# Maximum Number of Leaf Nodes: Limiting the total number of leaf nodes.
#
#
# Impurity Threshold: Stopping if the purity of the current node is below a certain threshold (i.e., the split doesn't improve the purity enough).
#
# Pre-pruning is simpler and faster than post-pruning, but it is greedy and may stop the growth too early, missing potentially good splits that occur deeper in the tree

# %% [markdown]
# Question 4:Write a Python program to train a Decision Tree Classifier using Gini
# Impurity as the criterion and print the feature importances (practical)

# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create Decision Tree Classifier using Gini impurity
clf = DecisionTreeClassifier(criterion='gini', random_state=42)

# Train the model
clf.fit(X_train, y_train)

# Print feature importances
print("Feature Importances:")
for feature, importance in zip(iris.feature_names, clf.feature_importances_):
    print(f"{feature}: {importance:.4f}")

# Evaluate model accuracy
accuracy = clf.score(X_test, y_test)
print(f"\nModel Accuracy: {accuracy:.2f}")
# Out:
# Feature Importances:
# sepal length (cm): 0.0000
# sepal width (cm): 0.0191
# petal length (cm): 0.8933
# petal width (cm): 0.0876
#
# Model Accuracy: 1.00

# %% [markdown]
# Question 5: What is a Support Vector Machine (SVM)?

# %% [markdown]
# A Support Vector Machine (SVM) is a powerful supervised machine learning algorithm primarily used for classification and regression.
#
# Key Concepts:
#
#
# Optimal Separating Hyperplane: In a classification task, an SVM aims to find the optimal separating hyperplane that best divides the data points into their respective classes.
#
# Maximum Margin: The "optimal" hyperplane is the one that has the largest distance to the nearest training data points of any class. This distance is called the margin. Maximizing this margin improves the generalization ability of the classifier.
#
#
# Support Vectors: The data points that lie closest to the hyperplane and essentially define the margin are called Support Vectors. These are the critical elements of the training set, as the hyperplane is completely determined by them.
#
# SVMs can perform both linear and non-linear classification. For non-linear data, SVM uses the Kernel Trick (see Q6) to implicitly map the data into a higher-dimensional feature space where a linear separation might be possible

# %% [markdown]
# Question 6: What is the Kernel Trick in SVM?

# %% [markdown]
# Answer:
#
# The Kernel Trick is a fundamental technique that allows Support Vector Machines (SVMs) to effectively classify data that is not linearly separable in its original input space.
#
# Mechanism:
#
#
# Implicit Mapping: The core idea is to map the original low-dimensional input features into a much higher-dimensional feature space where the data points might become linearly separable.
#
#
# Kernel Function: Instead of explicitly performing this computationally expensive mapping, the Kernel Trick uses a Kernel Function (e.g., Polynomial, Radial Basis Function/RBF). This function calculates the dot product of the data points in the high-dimensional space using only the coordinates of the data points in the original low-dimensional space.
#
#
# Computational Efficiency: This "trick" avoids the heavy computation of transforming the data and working in the high-dimensional space, thereby maintaining computational efficiency while allowing SVM to learn non-linear decision boundaries.

# %% [markdown]
# Question 7: Write a Python program to train two SVM classifiers with Linear and RBF kernels on the Wine dataset, then compare their accuracies.

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load data
X, y = load_wine(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train two SVMs
svm_linear = SVC(kernel='linear').fit(X_train, y_train)
svm_rbf = SVC(kernel='rbf').fit(X_train, y_train)

# Compare accuracies
print("Linear Kernel Accuracy:", accuracy_score(y_test, svm_linear.predict(X_test)))
print("RBF Kernel Accuracy:", accuracy_score(y_test, svm_rbf.predict(X_test)))
# Out:
# Linear Kernel Accuracy: 0.9814814814814815
# RBF Kernel Accuracy: 0.7592592592592593

# %% [markdown]
# Question 8: What is the Naïve Bayes classifier, and why is it called "Naïve"?

# %% [markdown]
# The Naïve Bayes classifier is a family of probabilistic classifiers based on Bayes' Theorem26. It is one of the simplest yet surprisingly effective classification algorithms.Bayes' Theorem:The classifier computes the probability of a data point belonging to a class $C_k$, given the features $\mathbf{x} = (x_1, x_2, \dots, x_n)$, using:$$P(C_k | \mathbf{x}) = \frac{P(\mathbf{x} | C_k) P(C_k)}{P(\mathbf{x})}$$The classifier then assigns the class with the highest posterior probability $\text{argmax}_{k} P(C_k | \mathbf{x})$.
#
#
# Why is it called "Naïve"?
#
# The classifier is called "Naïve" because of the fundamental, simplifying assumption it makes: that all features are conditionally independent of one another, given the class label

# %% [markdown]
# Question 9: Explain the differences between Gaussian Naïve Bayes, Multinomial Naïve
# Bayes, and Bernoulli Naïve Bayes

# %% [markdown]
# 1. Gaussian Naïve Bayes:
# This type of Naïve Bayes is used when the features are continuous (numerical) and follow a normal (Gaussian) distribution.
# For example, it is suitable for datasets where features like height, weight, blood pressure, or age are used.
# It assumes that each feature’s values are distributed according to a bell-shaped curve.
#
# 2. Multinomial Naïve Bayes:
# This model is used for discrete features that represent counts or frequencies, such as the number of times a word appears in a document.
# It is mostly used in text classification problems like spam detection or sentiment analysis, where the features are word counts or term frequencies.
#
# 3. Bernoulli Naïve Bayes:
# This type is used when the features are binary (0 or 1) — meaning each feature represents whether an event occurred or not.
# It is suitable for datasets where features indicate presence or absence, such as whether a specific word appears in an email (1 for present, 0 for absent).

# %% [markdown]
# Question 10: Breast Cancer Dataset
# Write a Python program to train a Gaussian Naïve Bayes classifier on the Breast Cancer
# dataset and evaluate accuracy.
# Hint:Use GaussianNB() from sklearn.naive_bayes and the Breast Cancer dataset from
# sklearn.datasets.
# (Include your Python code and output in the code box below.)

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# 1. Load the Breast Cancer dataset
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

# 2. Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# 3. Initialize and train the Gaussian Naïve Bayes Classifier
# GNB is chosen because the Breast Cancer features are continuous and often assume a normal distribution
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# 4. Make predictions and evaluate accuracy
y_pred = gnb.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("--- Gaussian Naïve Bayes (Breast Cancer Dataset) ---")
print(f"GNB Model Accuracy: {accuracy:.4f}")
# Out:
# --- Gaussian Naïve Bayes (Breast Cancer Dataset) ---
# GNB Model Accuracy: 0.9415
